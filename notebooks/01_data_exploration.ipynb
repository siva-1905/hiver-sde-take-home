# %%
import pandas as pd

df = pd.read_csv("../data/raw/sample.csv")

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

print("\nInbound distribution:")
print(df["inbound"].value_counts())

df.head()
# Out:
# Shape: (93, 7)
#
# Columns:
# ['tweet_id', 'author_id', 'inbound', 'created_at', 'text', 'response_tweet_id', 'in_response_to_tweet_id']
#
# Inbound distribution:
# inbound
# True     49
# False    44
# Name: count, dtype: int64
#    tweet_id     author_id  inbound                      created_at  \
# 0    119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
#
#                                                 text response_tweet_id  \
# 0  @AppleSupport causing the reply to be disregar...            119236
# 1  @105835 Your business means a lot to us. Pleas...               NaN
# 2  @76328 I really hope you all change but I'm su...            119238
# 3  @105836 LiveChat is online at the moment - htt...            119241
# 4  @VirginTrains see attached error message. I've...            119243
#
#    in_response_to_tweet_id
# 0                      NaN
# 1                 119239.0
# 2                      NaN
# 3                 119242.0
# 4                 119240.0

# %%
print("Number of unique authors:", df["author_id"].nunique())

print("\nAuthors:")
print(df["author_id"].value_counts().head(20))
# Out:
# Number of unique authors: 42
#
# Authors:
# author_id
# AppleSupport       13
# SpotifyCares        8
# Tesco               8
# VirginTrains        4
# 105840              4
# 105847              4
# 105855              4
# 105836              3
# British_Airways     3
# 105848              3
# 105856              3
# 105842              2
# 105844              2
# 105850              2
# 105854              2
# 105857              2
# 105834              1
# ChaseSupport        1
# 105835              1
# 105837              1
# Name: count, dtype: int64

# %%
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# tweet_id                    0
# author_id                   0
# inbound                     0
# created_at                  0
# text                        0
# response_tweet_id          28
# in_response_to_tweet_id    25
# dtype: int64

# %%
print("\nCustomer messages:")
print(df[df["inbound"] == True][["author_id", "text"]].head(10))
# Out:
# Customer messages:
#    author_id                                               text
# 0     105834  @AppleSupport causing the reply to be disregar...
# 2     105835  @76328 I really hope you all change but I'm su...
# 4     105836  @VirginTrains see attached error message. I've...
# 6     105836  @VirginTrains yep, I've tried laptop too sever...
# 8     105836  @VirginTrains I still haven't heard &amp; the ...
# 11    105837  @105838 @AppleSupport Me too am suffering , ho...
# 12    105838  @AppleSupport hi #apple, I’ve a concern about ...
# 14    105839  I just updated my phone and suddenly everythin...
# 16    105840  @SpotifyCares Thanks! Version 8.4.22.857 armv7...
# 18    105840  @SpotifyCares No, but I've moved speaker to ab...

# %%
df["author_id"].value_counts()
# Out:
# author_id
# AppleSupport       13
# SpotifyCares        8
# Tesco               8
# VirginTrains        4
# 105840              4
# 105847              4
# 105855              4
# 105836              3
# British_Airways     3
# 105848              3
# 105856              3
# 105842              2
# 105844              2
# 105850              2
# 105854              2
# 105857              2
# 105834              1
# ChaseSupport        1
# 105835              1
# 105837              1
# 105838              1
# 105839              1
# 105841              1
# 105843              1
# O2                  1
# 82476               1
# comcastcares        1
# 105845              1
# sprintcare          1
# 105676              1
# 105846              1
# 105849              1
# SouthwestAir        1
# 105851              1
# 105852              1
# Ask_Spectrum        1
# HPSupport           1
# 105858              1
# UPSHelp             1
# 105859              1
# 105860              1
# 105861              1
# Name: count, dtype: int64
